# %%
# !unzip XLM-main.zip
# !chmod -R 777 XLM-main/
# %cd XLM-main
# Thai - https://github.com/PyThaiNLP/pythainlp
# !pip install pythainlp
# Chinese
# %cd tools/
# !wget https://nlp.stanford.edu/software/stanford-segmenter-2018-10-16.zip
# !unzip stanford-segmenter-2018-10-16.zip
# %cd ../
# Out:
# Archive:  XLM-main.zip
#    creating: XLM-main/
#   inflating: XLM-main/.gitignore
#   inflating: XLM-main/CODE_OF_CONDUCT.md
#   inflating: XLM-main/CONTRIBUTING.md
#   inflating: XLM-main/generate-embeddings.ipynb
#   inflating: XLM-main/get-data-glue.sh
#   inflating: XLM-main/get-data-nmt.sh
#   inflating: XLM-main/get-data-para.sh
#   inflating: XLM-main/get-data-wiki.sh
#   inflating: XLM-main/get-data-xnli.sh
#   inflating: XLM-main/glue-xnli.py
#   inflating: XLM-main/install-tools.sh
#   inflating: XLM-main/LICENSE
#   inflating: XLM-main/PKM-layer.ipynb
#   inflating: XLM-main/prepare-glue.sh
#   inflating: XLM-main/prepare-xnli.sh
#   inflating: XLM-main/preprocess.py
#   inflating: XLM-main/README.md
#   inflating: XLM-main/setup.py
#  extracting: XLM-main/src
#    creating: XLM-main/tools/
#   inflating: XLM-main/tools/lowercase_and_remove_accent.py
#   inflating: XLM-main/tools/README.md
#   inflating: XLM-main/tools/segment_th.py
#   inflating: XLM-main/tools/tokenize.sh
#   inflating: XLM-main/train.py
#   inflating: XLM-main/translate.py
#    creating: XLM-main/xlm/
#    creating: XLM-main/xlm/data/
#   inflating: XLM-main/xlm/data/dataset.py
#   inflating: XLM-main/xlm/data/dictionary.py
#   inflating: XLM-main/xlm/data/loader.py
#  extracting: XLM-main/xlm/data/__init__.py
#    creating: XLM-main/xlm/evaluation/
#   inflating: XLM-main/xlm/evaluation/evaluator.py
#   inflating: XLM-main/xlm/evaluation/glue.py
#   inflating: XLM-main/xlm/evaluation/multi-bleu.perl
#   inflating: XLM-main/xlm/evaluation/xnli.py
#  extracting: XLM-main/xlm/evaluation/__init__.py
#   inflating: XLM-main/xlm/logger.py
#    creating: XLM-main/xlm/model/
#   inflating: XLM-main/xlm/model/embedder.py
#    creating: XLM-main/xlm/model/memory/
#   inflating: XLM-main/xlm/model/memory/memory.py
#   inflating: XLM-main/xlm/model/memory/query.py
#   inflating: XLM-main/xlm/model/memory/utils.py
#   inflating: XLM-main/xlm/model/memory/__init__.py
#   inflating: XLM-main/xlm/model/pretrain.py
#   inflating: XLM-main/xlm/model/transformer.py
#   inflating: XLM-main/xlm/model/__init__.py
#   inflating: XLM-main/xlm/optim.py
#   inflating: XLM-main/xlm/slurm.py
#   inflating: XLM-main/xlm/trainer.py
#   inflating: XLM-main/xlm/utils.py
#  extracting: XLM-main/xlm/__init__.py
# /content/XLM-main
# Collecting pythainlp
#   Downloading pythainlp-3.0.5-py3-none-any.whl (11.5 MB)
#      |████████████████████████████████| 11.5 MB 1.7 MB/s
# Collecting tinydb>=3.0
#   Downloading tinydb-4.7.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.7/dist-packages (from pythainlp) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->pythainlp) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->pythainlp) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->pythainlp) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->pythainlp) (2.10)
# Requirement already satisfied: typing-extensions<5.0.0,>=3.10.0 in /usr/local/lib/python3.7/dist-packages (from tinydb>=3.0->pythainlp) (4.1.1)
# Installing collected packages: tinydb, pythainlp
# Successfully installed pythainlp-3.0.5 tinydb-4.7.0
# /content/XLM-main/tools
# --2022-04-15 00:52:49--  https://nlp.stanford.edu/software/stanford-segmenter-2018-10-16.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: https://downloads.cs.stanford.edu/nlp/software/stanford-segmenter-2018-10-16.zip [following]
# --2022-04-15 00:52:49--  https://downloads.cs.stanford.edu/nlp/software/stanford-segmenter-2018-10-16.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 268741046 (256M) [application/zip]
# Saving to: ‘stanford-segmenter-2018-10-16.zip’
#
# stanford-segmenter- 100%[===================>] 256.29M  5.12MB/s    in 46s
#
# 2022-04-15 00:53:36 (5.56 MB/s) - ‘stanford-segmenter-2018-10-16.zip’ saved [268741046/268741046]
#
# Archive:  stanford-segmenter-2018-10-16.zip
#    creating: stanford-segmenter-2018-10-16/
#   inflating: stanford-segmenter-2018-10-16/segment.sh
#   inflating: stanford-segmenter-2018-10-16/stanford-segmenter-3.9.2.jar
#    creating: stanford-segmenter-2018-10-16/data/
#   inflating: stanford-segmenter-2018-10-16/data/pku.gz
#    creating: stanford-segmenter-2018-10-16/data/dict/
#   inflating: stanford-segmenter-2018-10-16/data/dict/in.pk.gb
#   inflating: stanford-segmenter-2018-10-16/data/dict/in.as
#   inflating: stanford-segmenter-2018-10-16/data/dict/in.hk
#   inflating: stanford-segmenter-2018-10-16/data/dict/in.pk
#   inflating: stanford-segmenter-2018-10-16/data/dict/character_list.hk
#   inflating: stanford-segmenter-2018-10-16/data/dict/char.ctb.list
#    creating: stanford-segmenter-2018-10-16/data/dict/pos_close/
#   inflating: stanford-segmenter-2018-10-16/data/dict/pos_close/char.ctb.list
#   inflating: stanford-segmenter-2018-10-16/data/dict/hk.non
#   inflating: stanford-segmenter-2018-10-16/data/dict/in.ctb.gb18030
#   inflating: stanford-segmenter-2018-10-16/data/dict/character_list
#   inflating: stanford-segmenter-2018-10-16/data/dict/character_list.gb18030
#    creating: stanford-segmenter-2018-10-16/data/dict/pos_open/
#   inflating: stanford-segmenter-2018-10-16/data/dict/pos_open/character_list.hk
#   inflating: stanford-segmenter-2018-10-16/data/dict/pos_open/character_list.pku.utf8
#   inflating: stanford-segmenter-2018-10-16/data/dict/pos_open/character_list.pku.gb
#   inflating: stanford-segmenter-2018-10-16/data/dict/pos_open/character_list.as
#   inflating: stanford-segmenter-2018-10-16/data/dict/Makefile
#   inflating: stanford-segmenter-2018-10-16/data/dict/character_list.as
#   inflating: stanford-segmenter-2018-10-16/data/dict/ctb.non
#   inflating: stanford-segmenter-2018-10-16/data/dict/as.non
#   inflating: stanford-segmenter-2018-10-16/data/dict/in.ctb
#   inflating: stanford-segmenter-2018-10-16/data/dict/pku.non
#   inflating: stanford-segmenter-2018-10-16/data/ctb.gz
#   inflating: stanford-segmenter-2018-10-16/data/norm.simp.utf8
#   inflating: stanford-segmenter-2018-10-16/data/arabic-segmenter-atb+bn+arztrain.ser.gz
#   inflating: stanford-segmenter-2018-10-16/data/ctb.prop
#   inflating: stanford-segmenter-2018-10-16/data/dict-chris6.ser.gz
#   inflating: stanford-segmenter-2018-10-16/data/pku.prop
#   inflating: stanford-segmenter-2018-10-16/build.xml
#    creating: stanford-segmenter-2018-10-16/arabic/
#   inflating: stanford-segmenter-2018-10-16/arabic/output_to_tedeval.py
#   inflating: stanford-segmenter-2018-10-16/arabic/tag_segmentation.py
#   inflating: stanford-segmenter-2018-10-16/arabic/train_ar_segmenter_da.sh
#   inflating: stanford-segmenter-2018-10-16/arabic/integrated_to_gold
#    creating: stanford-segmenter-2018-10-16/arabic/atb-diab-jhu2005-integrated/
#   inflating: stanford-segmenter-2018-10-16/arabic/atb-diab-jhu2005-integrated/dev
#   inflating: stanford-segmenter-2018-10-16/arabic/atb-diab-jhu2005-integrated/test
#   inflating: stanford-segmenter-2018-10-16/arabic/atb-diab-jhu2005-integrated/all
#   inflating: stanford-segmenter-2018-10-16/arabic/atb-diab-jhu2005-integrated/train
#   inflating: stanford-segmenter-2018-10-16/arabic/parse_integrated
#   inflating: stanford-segmenter-2018-10-16/arabic/tb-preproc
#   inflating: stanford-segmenter-2018-10-16/arabic/utf8utils.py
#   inflating: stanford-segmenter-2018-10-16/arabic/edits.py
#    creating: stanford-segmenter-2018-10-16/arabic/testfiles/
#   inflating: stanford-segmenter-2018-10-16/arabic/testfiles/arz-test.seg.utf8.txt
#   inflating: stanford-segmenter-2018-10-16/arabic/testfiles/atb-test.utf8.txt
#   inflating: stanford-segmenter-2018-10-16/arabic/testfiles/arz-test.utf8.txt
#   inflating: stanford-segmenter-2018-10-16/arabic/testfiles/atb-test.seg.utf8.txt
#   inflating: stanford-segmenter-2018-10-16/arabic/train_ar_segmenter.sh
#    creating: stanford-segmenter-2018-10-16/arabic/arz-habash-ddm-integrated/
#   inflating: stanford-segmenter-2018-10-16/arabic/arz-habash-ddm-integrated/dev
#   inflating: stanford-segmenter-2018-10-16/arabic/arz-habash-ddm-integrated/test
#   inflating: stanford-segmenter-2018-10-16/arabic/arz-habash-ddm-integrated/all
#   inflating: stanford-segmenter-2018-10-16/arabic/arz-habash-ddm-integrated/train
#    creating: stanford-segmenter-2018-10-16/arabic/bn-monroe-ddm-integrated/
#   inflating: stanford-segmenter-2018-10-16/arabic/bn-monroe-ddm-integrated/dev
#   inflating: stanford-segmenter-2018-10-16/arabic/bn-monroe-ddm-integrated/test
#   inflating: stanford-segmenter-2018-10-16/arabic/bn-monroe-ddm-integrated/all
#   inflating: stanford-segmenter-2018-10-16/arabic/bn-monroe-ddm-integrated/train
#   inflating: stanford-segmenter-2018-10-16/stanford-segmenter-3.9.2-javadoc.jar
#   inflating: stanford-segmenter-2018-10-16/test.simp.utf8
#   inflating: stanford-segmenter-2018-10-16/README-Chinese.txt
#   inflating: stanford-segmenter-2018-10-16/README-Arabic.txt
#   inflating: stanford-segmenter-2018-10-16/stanford-segmenter-3.9.2-sources.jar
#   inflating: stanford-segmenter-2018-10-16/segment.bat
#   inflating: stanford-segmenter-2018-10-16/SegDemo.java
# /content/XLM-main

# %%
# 下载数据
# !./get-data-xnli.sh
# Out:
# Cloning Moses from GitHub repository...
# Cloning into 'mosesdecoder'...
# remote: Enumerating objects: 148090, done.
# remote: Counting objects: 100% (518/518), done.
# remote: Compressing objects: 100% (223/223), done.
# remote: Total 148090 (delta 319), reused 443 (delta 292), pack-reused 147572
# Receiving objects: 100% (148090/148090), 129.87 MiB | 17.69 MiB/s, done.
# Resolving deltas: 100% (114345/114345), done.
# Cloning fastBPE from GitHub repository...
# Cloning into 'fastBPE'...
# remote: Enumerating objects: 59, done.
# remote: Total 59 (delta 0), reused 0 (delta 0), pack-reused 59
# Unpacking objects: 100% (59/59), done.
# Compiling fastBPE...
# Cloning WMT16 preprocessing scripts...
# Cloning into 'wmt16-scripts'...
# remote: Enumerating objects: 151, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 151 (delta 0), reused 1 (delta 0), pack-reused 146
# Receiving objects: 100% (151/151), 3.79 MiB | 17.89 MiB/s, done.
# Resolving deltas: 100% (76/76), done.
# Cloning WikiExtractor from GitHub repository...
# Cloning into 'wikiextractor'...
# remote: Enumerating objects: 766, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 766 (delta 13), reused 11 (delta 6), pack-reused 741
# Receiving objects: 100% (766/766), 1.31 MiB | 18.41 MiB/s, done.
# Resolving deltas: 100% (446/446), done.
# --2022-04-15 00:54:04--  https://dl.fbaipublicfiles.com/XNLI/XNLI-MT-1.0.zip
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.22.75.142, 172.67.9.4, 104.22.74.142, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.75.142|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 466098360 (445M) [application/zip]
# Saving to: ‘/content/XLM-main/data/xnli/XNLI-MT-1.0.zip’
#
# XNLI-MT-1.0.zip     100%[===================>] 444.51M  49.3MB/s    in 9.7s
#
# 2022-04-15 00:54:14 (45.8 MB/s) - ‘/content/XLM-main/data/xnli/XNLI-MT-1.0.zip’ saved [466098360/466098360]
#
# Archive:  /content/XLM-main/data/xnli/XNLI-MT-1.0.zip
#    creating: /content/XLM-main/data/xnli/XNLI-MT-1.0/
#    creating: /content/XLM-main/data/xnli/XNLI-MT-1.0/multinli/
#   inflating: /content/XLM-main/data/xnli/XNLI-MT-1.0/multinli/multinli.train.de.tsv
#    creating: /content/XLM-main/data/xnli/__MACOSX/
#    creating: /content/XLM-main/data/xnli/__MACOSX/XNLI-MT-1.0/
#    creating: /content/XLM-main/data/xnli/__MACOSX/XNLI-MT-1.0/multinli/
#   inflating: /content/XLM-main/data/xnli/__MACOSX/XNLI-MT-1.0/multinli/._multinli.train.de.tsv
#   inflating: /content/XLM-main/data/xnli/XNLI-MT-1.0/multinli/multinli.train.es.tsv
#   inflating: /content/XLM-main/data/xnli/__MACOSX/XNLI-MT-1.0/multinli/._multinli.train.es.tsv
#   inflating: /content/XLM-main/data/xnli/XNLI-MT-1.0/multinli/multinli.train.th.tsv
#   inflating: /content/XLM-main/data/xnli/XNLI-MT-1.0/multinli/multinli.train.bg.tsv
#   inflating: /content/XLM-main/data/xnli/__MACOSX/XNLI-MT-1.0/multinli/._multinli.train.bg.tsv
#   inflating: /content/XLM-main/data/xnli/XNLI-MT-1.0/multinli/multinli.train.vi.tsv
#   inflating: /content/XLM-main/data/xnli/__MACOSX/XNLI-MT-1.0/multinli/._multinli.train.vi.tsv
#   inflating: /content/XLM-main/data/xnli/XNLI-MT-1.0/multinli/multinli.train.ur.tsv
#   inflating: /content/XLM-main/data/xnli/__MACOSX/XNLI-MT-1.0/multinli/._multinli.train.ur.tsv
#   inflating: /content/XLM-main/data/xnli/XNLI-MT-1.0/multinli/multinli.train.zh.tsv
#   inflating: /content/XLM-main/data/xnli/__MACOSX/XNLI-MT-1.0/multinli/._multinli.train.zh.tsv
#   inflating: /content/XLM-main/data/xnli/XNLI-MT-1.0/multinli/multinli.train.ar.tsv
#   inflating: /content/XLM-main/data/xnli/__MACOSX/XNLI-MT-1.0/multinli/._multinli.train.ar.tsv
#   inflating: /content/XLM-main/data/xnli/XNLI-MT-1.0/multinli/multinli.train.tr.tsv
#   inflating: /content/XLM-main/data/xnli/__MACOSX/XNLI-MT-1.0/multinli/._multinli.train.tr.tsv
#   inflating: /content/XLM-main/data/xnli/XNLI-MT-1.0/multinli/multinli.train.ru.tsv
#   inflating: /content/XLM-main/data/xnli/__MACOSX/XNLI-MT-1.0/multinli/._multinli.train.ru.tsv
#   inflating: /content/XLM-main/data/xnli/XNLI-MT-1.0/multinli/multinli.train.fr.tsv
#   inflating: /content/XLM-main/data/xnli/__MACOSX/XNLI-MT-1.0/multinli/._multinli.train.fr.tsv
#   inflating: /content/XLM-main/data/xnli/XNLI-MT-1.0/multinli/multinli.train.sw.tsv
#   inflating: /content/XLM-main/data/xnli/__MACOSX/XNLI-MT-1.0/multinli/._multinli.train.sw.tsv
#   inflating: /content/XLM-main/data/xnli/XNLI-MT-1.0/multinli/multinli.train.el.tsv
#   inflating: /content/XLM-main/data/xnli/__MACOSX/XNLI-MT-1.0/multinli/._multinli.train.el.tsv
#   inflating: /content/XLM-main/data/xnli/XNLI-MT-1.0/multinli/multinli.train.hi.tsv
#   inflating: /content/XLM-main/data/xnli/__MACOSX/XNLI-MT-1.0/multinli/._multinli.train.hi.tsv
#   inflating: /content/XLM-main/data/xnli/XNLI-MT-1.0/multinli/multinli.train.en.tsv
#   inflating: /content/XLM-main/data/xnli/__MACOSX/XNLI-MT-1.0/._multinli
#   inflating: /content/XLM-main/data/xnli/XNLI-MT-1.0/.DS_Store
#   inflating: /content/XLM-main/data/xnli/__MACOSX/XNLI-MT-1.0/._.DS_Store
#    creating: /content/XLM-main/data/xnli/XNLI-MT-1.0/xnli/
#   inflating: /content/XLM-main/data/xnli/XNLI-MT-1.0/xnli/xnli.dev.en.jsonl
#   inflating: /content/XLM-main/data/xnli/XNLI-MT-1.0/xnli/.DS_Store
#    creating: /content/XLM-main/data/xnli/__MACOSX/XNLI-MT-1.0/xnli/
#   inflating: /content/XLM-main/data/xnli/__MACOSX/XNLI-MT-1.0/xnli/._.DS_Store
#   inflating: /content/XLM-main/data/xnli/XNLI-MT-1.0/xnli/xnli.test.en.tsv
#   inflating: /content/XLM-main/data/xnli/XNLI-MT-1.0/xnli/xnli.dev.en.tsv
#   inflating: /content/XLM-main/data/xnli/XNLI-MT-1.0/xnli/xnli.test.en.jsonl
#   inflating: /content/XLM-main/data/xnli/__MACOSX/XNLI-MT-1.0/._xnli
#   inflating: /content/XLM-main/data/xnli/__MACOSX/._XNLI-MT-1.0
# --2022-04-15 00:54:32--  https://dl.fbaipublicfiles.com/XNLI/XNLI-1.0.zip
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.22.75.142, 172.67.9.4, 104.22.74.142, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.75.142|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17865352 (17M) [application/zip]
# Saving to: ‘/content/XLM-main/data/xnli/XNLI-1.0.zip’
#
# XNLI-1.0.zip        100%[===================>]  17.04M  33.8MB/s    in 0.5s
#
# 2022-04-15 00:54:32 (33.8 MB/s) - ‘/content/XLM-main/data/xnli/XNLI-1.0.zip’ saved [17865352/17865352]
#
# Archive:  /content/XLM-main/data/xnli/XNLI-1.0.zip
#    creating: /content/XLM-main/data/xnli/XNLI-1.0/
#   inflating: /content/XLM-main/data/xnli/XNLI-1.0/.DS_Store
#    creating: /content/XLM-main/data/xnli/__MACOSX/XNLI-1.0/
#   inflating: /content/XLM-main/data/xnli/__MACOSX/XNLI-1.0/._.DS_Store
#   inflating: /content/XLM-main/data/xnli/XNLI-1.0/xnli.dev.tsv
#   inflating: /content/XLM-main/data/xnli/__MACOSX/XNLI-1.0/._xnli.dev.tsv
#   inflating: /content/XLM-main/data/xnli/XNLI-1.0/xnli.dev.jsonl
#   inflating: /content/XLM-main/data/xnli/XNLI-1.0/README.md
#   inflating: /content/XLM-main/data/xnli/__MACOSX/XNLI-1.0/._README.md
#   inflating: /content/XLM-main/data/xnli/XNLI-1.0/xnli.test.jsonl
#   inflating: /content/XLM-main/data/xnli/XNLI-1.0/xnli.test.tsv
#   inflating: /content/XLM-main/data/xnli/__MACOSX/XNLI-1.0/._xnli.test.tsv
#   inflating: /content/XLM-main/data/xnli/__MACOSX/._XNLI-1.0
# *** Preparing English train set ****
# *** Preparing ar validation and test sets ***
# Tokenizer Version 1.1
# Language: ar
# Number of threads: 8
# WARNING: No known abbreviations for language 'ar', attempting fall-back to English version...
# Tokenizer Version 1.1
# Language: ar
# Number of threads: 8
# WARNING: No known abbreviations for language 'ar', attempting fall-back to English version...
# Tokenizer Version 1.1
# Language: ar
# Number of threads: 8
# WARNING: No known abbreviations for language 'ar', attempting fall-back to English version...
# Tokenizer Version 1.1
# Language: ar
# Number of threads: 8
# WARNING: No known abbreviations for language 'ar', attempting fall-back to English version...
# *** Preparing bg validation and test sets ***
# Tokenizer Version 1.1
# Language: bg
# Number of threads: 8
# WARNING: No known abbreviations for language 'bg', attempting fall-back to English version...
# Tokenizer Version 1.1
# Language: bg
# Number of threads: 8
# WARNING: No known abbreviations for language 'bg', attempting fall-back to English version...
# Tokenizer Version 1.1
# Language: bg
# Number of threads: 8
# WARNING: No known abbreviations for language 'bg', attempting fall-back to English version...
# Tokenizer Version 1.1
# Language: bg
# Number of threads: 8
# WARNING: No known abbreviations for language 'bg', attempting fall-back to English version...
# *** Preparing de validation and test sets ***
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
# Tokenizer Version 1.1
# Language: de
# Number of threads: 8
# *** Preparing el validation and test sets ***
# Tokenizer Version 1.1
# Language: el
# Number of threads: 8
# Tokenizer Version 1.1
# Language: el
# Number of threads: 8
# Tokenizer Version 1.1
# Language: el
# Number of threads: 8
# Tokenizer Version 1.1
# Language: el
# Number of threads: 8
# *** Preparing en validation and test sets ***
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
# *** Preparing es validation and test sets ***
# Tokenizer Version 1.1
# Language: es
# Number of threads: 8
# Tokenizer Version 1.1
# Language: es
# Number of threads: 8
# Tokenizer Version 1.1
# Language: es
# Number of threads: 8
# Tokenizer Version 1.1
# Language: es
# Number of threads: 8
# *** Preparing fr validation and test sets ***
# Tokenizer Version 1.1
# Language: fr
# Number of threads: 8
# Tokenizer Version 1.1
# Language: fr
# Number of threads: 8
# Tokenizer Version 1.1
# Language: fr
# Number of threads: 8
# Tokenizer Version 1.1
# Language: fr
# Number of threads: 8
# *** Preparing hi validation and test sets ***
# Tokenizer Version 1.1
# Language: hi
# Number of threads: 8
# Tokenizer Version 1.1
# Language: hi
# Number of threads: 8
# Tokenizer Version 1.1
# Language: hi
# Number of threads: 8
# Tokenizer Version 1.1
# Language: hi
# Number of threads: 8
# *** Preparing ru validation and test sets ***
# Tokenizer Version 1.1
# Language: ru
# Number of threads: 8
# Tokenizer Version 1.1
# Language: ru
# Number of threads: 8
# Tokenizer Version 1.1
# Language: ru
# Number of threads: 8
# Tokenizer Version 1.1
# Language: ru
# Number of threads: 8
# *** Preparing sw validation and test sets ***
# Tokenizer Version 1.1
# Language: sw
# Number of threads: 8
# WARNING: No known abbreviations for language 'sw', attempting fall-back to English version...
# Tokenizer Version 1.1
# Language: sw
# Number of threads: 8
# WARNING: No known abbreviations for language 'sw', attempting fall-back to English version...
# Tokenizer Version 1.1
# Language: sw
# Number of threads: 8
# WARNING: No known abbreviations for language 'sw', attempting fall-back to English version...
# Tokenizer Version 1.1
# Language: sw
# Number of threads: 8
# WARNING: No known abbreviations for language 'sw', attempting fall-back to English version...
# *** Preparing th validation and test sets ***
# *** Preparing tr validation and test sets ***
# Tokenizer Version 1.1
# Language: tr
# Number of threads: 8
# WARNING: No known abbreviations for language 'tr', attempting fall-back to English version...
# Tokenizer Version 1.1
# Language: tr
# Number of threads: 8
# WARNING: No known abbreviations for language 'tr', attempting fall-back to English version...
# Tokenizer Version 1.1
# Language: tr
# Number of threads: 8
# WARNING: No known abbreviations for language 'tr', attempting fall-back to English version...
# Tokenizer Version 1.1
# Language: tr
# Number of threads: 8
# WARNING: No known abbreviations for language 'tr', attempting fall-back to English version...
# *** Preparing ur validation and test sets ***
# Tokenizer Version 1.1
# Language: ur
# Number of threads: 8
# WARNING: No known abbreviations for language 'ur', attempting fall-back to English version...
# Tokenizer Version 1.1
# Language: ur
# Number of threads: 8
# WARNING: No known abbreviations for language 'ur', attempting fall-back to English version...
# Tokenizer Version 1.1
# Language: ur
# Number of threads: 8
# WARNING: No known abbreviations for language 'ur', attempting fall-back to English version...
# Tokenizer Version 1.1
# Language: ur
# Number of threads: 8
# WARNING: No known abbreviations for language 'ur', attempting fall-back to English version...
# *** Preparing vi validation and test sets ***
# Tokenizer Version 1.1
# Language: vi
# Number of threads: 8
# WARNING: No known abbreviations for language 'vi', attempting fall-back to English version...
# Tokenizer Version 1.1
# Language: vi
# Number of threads: 8
# WARNING: No known abbreviations for language 'vi', attempting fall-back to English version...
# Tokenizer Version 1.1
# Language: vi
# Number of threads: 8
# WARNING: No known abbreviations for language 'vi', attempting fall-back to English version...
# Tokenizer Version 1.1
# Language: vi
# Number of threads: 8
# WARNING: No known abbreviations for language 'vi', attempting fall-back to English version...
# *** Preparing zh validation and test sets ***
# (PKU):
# File: /dev/stdin
# Encoding: UTF-8
# -------------------------------
# Invoked on Fri Apr 15 00:56:08 UTC 2022 with arguments: -sighanCorporaDict /content/XLM-main/tools/stanford-segmenter-2018-10-16/data -textFile /dev/stdin -inputEncoding UTF-8 -sighanPostProcessing true -keepAllWhitespaces false -loadClassifier /content/XLM-main/tools/stanford-segmenter-2018-10-16/data/pku.gz -serDictionary /content/XLM-main/tools/stanford-segmenter-2018-10-16/data/dict-chris6.ser.gz
# inputEncoding=UTF-8
# sighanCorporaDict=/content/XLM-main/tools/stanford-segmenter-2018-10-16/data
# loadClassifier=/content/XLM-main/tools/stanford-segmenter-2018-10-16/data/pku.gz
# serDictionary=/content/XLM-main/tools/stanford-segmenter-2018-10-16/data/dict-chris6.ser.gz
# sighanPostProcessing=true
# textFile=/dev/stdin
# keepAllWhitespaces=false
# Loading classifier from /content/XLM-main/tools/stanford-segmenter-2018-10-16/data/pku.gz ... done [11.3 sec].
# Loading Chinese dictionaries from 1 file:
#   /content/XLM-main/tools/stanford-segmenter-2018-10-16/data/dict-chris6.ser.gz
# Done. Unique words in ChineseDictionary is: 423200.
# Loading unnormalized dictionary from /content/XLM-main/tools/stanford-segmenter-2018-10-16/data/dict/pku.non
# INFO: flags.usePk=true | building NonDict2 from /content/XLM-main/tools/stanford-segmenter-2018-10-16/data/dict/pku.non
# Loading character dictionary file from /content/XLM-main/tools/stanford-segmenter-2018-10-16/data/dict/pos_open/character_list.pku.utf8 [done].
# Loading affix dictionary from /content/XLM-main/tools/stanford-segmenter-2018-10-16/data/dict/in.pk [done].
# CRFClassifier tagged 81861 words in 2490 documents at 7906.22 words per second.
# (PKU):
# File: /dev/stdin
# Encoding: UTF-8
# -------------------------------
# Invoked on Fri Apr 15 00:56:31 UTC 2022 with arguments: -sighanCorporaDict /content/XLM-main/tools/stanford-segmenter-2018-10-16/data -textFile /dev/stdin -inputEncoding UTF-8 -sighanPostProcessing true -keepAllWhitespaces false -loadClassifier /content/XLM-main/tools/stanford-segmenter-2018-10-16/data/pku.gz -serDictionary /content/XLM-main/tools/stanford-segmenter-2018-10-16/data/dict-chris6.ser.gz
# inputEncoding=UTF-8
# sighanCorporaDict=/content/XLM-main/tools/stanford-segmenter-2018-10-16/data
# loadClassifier=/content/XLM-main/tools/stanford-segmenter-2018-10-16/data/pku.gz
# serDictionary=/content/XLM-main/tools/stanford-segmenter-2018-10-16/data/dict-chris6.ser.gz
# sighanPostProcessing=true
# textFile=/dev/stdin
# keepAllWhitespaces=false
# Loading classifier from /content/XLM-main/tools/stanford-segmenter-2018-10-16/data/pku.gz ... done [11.1 sec].
# Loading Chinese dictionaries from 1 file:
#   /content/XLM-main/tools/stanford-segmenter-2018-10-16/data/dict-chris6.ser.gz
# Done. Unique words in ChineseDictionary is: 423200.
# Loading unnormalized dictionary from /content/XLM-main/tools/stanford-segmenter-2018-10-16/data/dict/pku.non
# INFO: flags.usePk=true | building NonDict2 from /content/XLM-main/tools/stanford-segmenter-2018-10-16/data/dict/pku.non
# Loading character dictionary file from /content/XLM-main/tools/stanford-segmenter-2018-10-16/data/dict/pos_open/character_list.pku.utf8 [done].
# Loading affix dictionary from /content/XLM-main/tools/stanford-segmenter-2018-10-16/data/dict/in.pk [done].
# CRFClassifier tagged 40896 words in 2490 documents at 6163.68 words per second.
# (PKU):
# File: /dev/stdin
# Encoding: UTF-8
# -------------------------------
# Invoked on Fri Apr 15 00:56:50 UTC 2022 with arguments: -sighanCorporaDict /content/XLM-main/tools/stanford-segmenter-2018-10-16/data -textFile /dev/stdin -inputEncoding UTF-8 -sighanPostProcessing true -keepAllWhitespaces false -loadClassifier /content/XLM-main/tools/stanford-segmenter-2018-10-16/data/pku.gz -serDictionary /content/XLM-main/tools/stanford-segmenter-2018-10-16/data/dict-chris6.ser.gz
# inputEncoding=UTF-8
# sighanCorporaDict=/content/XLM-main/tools/stanford-segmenter-2018-10-16/data
# loadClassifier=/content/XLM-main/tools/stanford-segmenter-2018-10-16/data/pku.gz
# serDictionary=/content/XLM-main/tools/stanford-segmenter-2018-10-16/data/dict-chris6.ser.gz
# sighanPostProcessing=true
# textFile=/dev/stdin
# keepAllWhitespaces=false
# Loading classifier from /content/XLM-main/tools/stanford-segmenter-2018-10-16/data/pku.gz ... done [11.4 sec].
# Loading Chinese dictionaries from 1 file:
#   /content/XLM-main/tools/stanford-segmenter-2018-10-16/data/dict-chris6.ser.gz
# Done. Unique words in ChineseDictionary is: 423200.
# Loading unnormalized dictionary from /content/XLM-main/tools/stanford-segmenter-2018-10-16/data/dict/pku.non
# INFO: flags.usePk=true | building NonDict2 from /content/XLM-main/tools/stanford-segmenter-2018-10-16/data/dict/pku.non
# Loading character dictionary file from /content/XLM-main/tools/stanford-segmenter-2018-10-16/data/dict/pos_open/character_list.pku.utf8 [done].
# Loading affix dictionary from /content/XLM-main/tools/stanford-segmenter-2018-10-16/data/dict/in.pk [done].
# CRFClassifier tagged 165576 words in 5010 documents at 10028.22 words per second.
# (PKU):
# File: /dev/stdin
# Encoding: UTF-8
# -------------------------------
# Invoked on Fri Apr 15 00:57:19 UTC 2022 with arguments: -sighanCorporaDict /content/XLM-main/tools/stanford-segmenter-2018-10-16/data -textFile /dev/stdin -inputEncoding UTF-8 -sighanPostProcessing true -keepAllWhitespaces false -loadClassifier /content/XLM-main/tools/stanford-segmenter-2018-10-16/data/pku.gz -serDictionary /content/XLM-main/tools/stanford-segmenter-2018-10-16/data/dict-chris6.ser.gz
# inputEncoding=UTF-8
# sighanCorporaDict=/content/XLM-main/tools/stanford-segmenter-2018-10-16/data
# loadClassifier=/content/XLM-main/tools/stanford-segmenter-2018-10-16/data/pku.gz
# serDictionary=/content/XLM-main/tools/stanford-segmenter-2018-10-16/data/dict-chris6.ser.gz
# sighanPostProcessing=true
# textFile=/dev/stdin
# keepAllWhitespaces=false
# Loading classifier from /content/XLM-main/tools/stanford-segmenter-2018-10-16/data/pku.gz ... done [11.3 sec].
# Loading Chinese dictionaries from 1 file:
#   /content/XLM-main/tools/stanford-segmenter-2018-10-16/data/dict-chris6.ser.gz
# Done. Unique words in ChineseDictionary is: 423200.
# Loading unnormalized dictionary from /content/XLM-main/tools/stanford-segmenter-2018-10-16/data/dict/pku.non
# INFO: flags.usePk=true | building NonDict2 from /content/XLM-main/tools/stanford-segmenter-2018-10-16/data/dict/pku.non
# Loading character dictionary file from /content/XLM-main/tools/stanford-segmenter-2018-10-16/data/dict/pos_open/character_list.pku.utf8 [done].
# Loading affix dictionary from /content/XLM-main/tools/stanford-segmenter-2018-10-16/data/dict/in.pk [done].
# CRFClassifier tagged 81941 words in 5010 documents at 7869.11 words per second.

# %%
# !./prepare-xnli.sh
# Out:
# --2022-04-15 00:57:42--  https://dl.fbaipublicfiles.com/XLM/codes_xnli_15
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.22.75.142, 172.67.9.4, 104.22.74.142, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.75.142|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1434601 (1.4M) [text/plain]
# Saving to: ‘/content/XLM-main/codes_xnli_15’
#
# codes_xnli_15       100%[===================>]   1.37M  --.-KB/s    in 0.04s
#
# 2022-04-15 00:57:42 (34.2 MB/s) - ‘/content/XLM-main/codes_xnli_15’ saved [1434601/1434601]
#
# --2022-04-15 00:57:42--  https://dl.fbaipublicfiles.com/XLM/vocab_xnli_15
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.22.75.142, 172.67.9.4, 104.22.74.142, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.75.142|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1548931 (1.5M) [text/plain]
# Saving to: ‘/content/XLM-main/vocab_xnli_15’
#
# vocab_xnli_15       100%[===================>]   1.48M  --.-KB/s    in 0.06s
#
# 2022-04-15 00:57:43 (25.3 MB/s) - ‘/content/XLM-main/vocab_xnli_15’ saved [1548931/1548931]
#
# Loading codes from /content/XLM-main/codes_xnli_15 ...
# Read 80000 codes from the codes file.
# Loading vocabulary from /content/XLM-main/data/processed/XLM15/eval/XNLI/f1.tok ...
# Read 43419 words (6125 unique) from text file.
# Applying BPE to /content/XLM-main/data/processed/XLM15/eval/XNLI/f1.tok ...
# Modified 43419 words from text file.
# Loading codes from /content/XLM-main/codes_xnli_15 ...
# Read 80000 codes from the codes file.
# Loading vocabulary from /content/XLM-main/data/processed/XLM15/eval/XNLI/f2.tok ...
# Read 22299 words (6988 unique) from text file.
# Applying BPE to /content/XLM-main/data/processed/XLM15/eval/XNLI/f2.tok ...
# Modified 22299 words from text file.
# @@ already in vocab
# @@ already in vocab
# @@ already in vocab
# @@ already in vocab
# @@ already in vocab
# @@ already in vocab
# @@ already in vocab
# INFO - 04/15/22 00:57:50 - 0:00:00 - Read 121328 words from the vocabulary file.
# WARNING - 04/15/22 00:57:50 - 0:00:00 - Skipped 18 empty lines!
#
# Saving the data to /content/XLM-main/data/processed/XLM15/eval/XNLI/valid.s1.ar.pkl ...
# INFO - 04/15/22 00:57:50 - 0:00:01 - 63624 words (121328 unique) in 2490 sentences.
# @@ already in vocab
# @@ already in vocab
# @@ already in vocab
# @@ already in vocab
# @@ already in vocab
# @@ already in vocab
# @@ already in vocab
# INFO - 04/15/22 00
content/XLM-main/data/processed/XLM15/eval/XNLI/f2.tok ...
# Read 49513 words (7447 unique) from text file.
# Applying BPE to /content/XLM-main/data/processed/XLM15/eval/XNLI/f2.tok ...
# Modified 49513 words from text file.
# @@ already in vocab
# @@ already in vocab
# @@ already in vocab
# @@ already in vocab
# @@ already in vocab
# @@ already in vocab
# @@ already in vocab
# INFO - 04/15/22 01:00:53 - 0:00:00 - Read 121328 words from the vocabulary file.
# WARNING - 04/15/22 01:00:53 - 0:00:00 - Skipped 18 empty lines!
#
# Saving the data to /content/XLM-main/data/processed/XLM15/eval/XNLI/test.s1.zh.pkl ...
# INFO - 04/15/22 01:00:53 - 0:00:01 - 128724 words (121328 unique) in 5010 sentences.
# @@ already in vocab
# @@ already in vocab
# @@ already in vocab
# @@ already in vocab
# @@ already in vocab
# @@ already in vocab
# @@ already in vocab
# INFO - 04/15/22 01:00:56 - 0:00:00 - Read 121328 words from the vocabulary file.
# WARNING - 04/15/22 01:00:56 - 0:00:00 - Skipped 18 empty lines!
#
# Saving the data to /content/XLM-main/data/processed/XLM15/eval/XNLI/test.s2.zh.pkl ...
# INFO - 04/15/22 01:00:56 - 0:00:01 - 63447 words (121328 unique) in 5010 sentences.

# %%
# !mv ./data/processed/XLM15/eval/XNLI XNLI
# !tar -zcvf xnli.tar.gz ./XNLI
# Out:
# ./XNLI/
# ./XNLI/valid.s2.hi
# ./XNLI/valid.label.hi
# ./XNLI/test.s1.vi
# ./XNLI/test.s1.fr
# ./XNLI/valid.s1.ur
# ./XNLI/valid.label.ur
# ./XNLI/valid.s1.de
# ./XNLI/test.s2.fr
# ./XNLI/valid.label.es
# ./XNLI/test.s2.en
# ./XNLI/valid.s1.bg.pkl
# ./XNLI/valid.s2.en
# ./XNLI/valid.s2.ar
# ./XNLI/test.s2.es.pkl
# ./XNLI/test.label.de
# ./XNLI/valid.s2.ar.pkl
# ./XNLI/valid.s1.vi.pkl
# ./XNLI/test.s2.tr
# ./XNLI/test.s2.bg.pkl
# ./XNLI/test.s2.de
# ./XNLI/valid.s2.de
# ./XNLI/valid.label.de
# ./XNLI/valid.s1.el
# ./XNLI/test.s2.fr.pkl
# ./XNLI/test.s1.ur
# ./XNLI/test.label.zh
# ./XNLI/test.label.es
# ./XNLI/valid.s2.el.pkl
# ./XNLI/valid.s1.vi
# ./XNLI/test.s1.hi
# ./XNLI/valid.s2.tr.pkl
# ./XNLI/test.s1.es.pkl
# ./XNLI/test.s2.el.pkl
# ./XNLI/train.s1.en.pkl
# ./XNLI/test.label.th
# ./XNLI/test.s1.th
# ./XNLI/test.label.ru
# ./XNLI/test.s2.hi.pkl
# ./XNLI/test.s1.th.pkl
# ./XNLI/test.s1.ru.pkl
# ./XNLI/test.s1.bg.pkl
# ./XNLI/test.s2.es
# ./XNLI/test.label.ur
# ./XNLI/valid.s2.el
# ./XNLI/test.s2.ur.pkl
# ./XNLI/valid.s2.ru
# ./XNLI/valid.label.sw
# ./XNLI/train.label.en
# ./XNLI/train.s2.en
# ./XNLI/valid.label.bg
# ./XNLI/valid.s2.es.pkl
# ./XNLI/valid.s1.en
# ./XNLI/test.s1.de
# ./XNLI/test.s1.vi.pkl
# ./XNLI/test.s2.ar
# ./XNLI/valid.s1.th.pkl
# ./XNLI/valid.s1.ur.pkl
# ./XNLI/valid.s1.ar.pkl
# ./XNLI/valid.s1.sw.pkl
# ./XNLI/valid.s2.th.pkl
# ./XNLI/test.s1.sw
# ./XNLI/test.s2.hi
# ./XNLI/test.s1.ar
# ./XNLI/test.label.tr
# ./XNLI/valid.label.vi
# ./XNLI/valid.label.ar
# ./XNLI/test.s2.sw.pkl
# ./XNLI/valid.s1.bg
# ./XNLI/test.s1.tr
# ./XNLI/test.s1.sw.pkl
# ./XNLI/valid.s2.sw.pkl
# ./XNLI/test.label.bg
# ./XNLI/valid.s2.es
# ./XNLI/test.s1.en.pkl
# ./XNLI/test.s2.de.pkl
# ./XNLI/test.s2.th.pkl
# ./XNLI/test.s2.zh
# ./XNLI/test.label.hi
# ./XNLI/test.s2.vi
# ./XNLI/test.s1.el
# ./XNLI/valid.s1.fr.pkl
# ./XNLI/valid.s1.fr
# ./XNLI/valid.label.fr
# ./XNLI/valid.s1.zh
# ./XNLI/test.s2.th
# ./XNLI/test.label.ar
# ./XNLI/valid.label.th
# ./XNLI/valid.s2.ru.pkl
# ./XNLI/valid.s1.es.pkl
# ./XNLI/valid.label.en
# ./XNLI/test.s2.ru
# ./XNLI/valid.s1.hi
# ./XNLI/test.s1.fr.pkl
# ./XNLI/test.s1.tr.pkl
# ./XNLI/test.label.fr
# ./XNLI/test.s1.de.pkl
# ./XNLI/valid.label.zh
# ./XNLI/valid.s2.vi.pkl
# ./XNLI/test.s1.ur.pkl
# ./XNLI/test.s2.zh.pkl
# ./XNLI/valid.s1.tr
# ./XNLI/valid.s2.bg.pkl
# ./XNLI/test.s2.ru.pkl
# ./XNLI/test.s1.ru
# ./XNLI/valid.s1.ru
# ./XNLI/valid.label.el
# ./XNLI/valid.s2.hi.pkl
# ./XNLI/valid.s2.fr
# ./XNLI/valid.label.tr
# ./XNLI/valid.s1.es
# ./XNLI/test.s1.ar.pkl
# ./XNLI/test.s2.bg
# ./XNLI/valid.s1.de.pkl
# ./XNLI/test.s2.el
# ./XNLI/valid.s2.vi
# ./XNLI/test.s2.en.pkl
# ./XNLI/test.label.en
# ./XNLI/test.s1.el.pkl
# ./XNLI/valid.s1.zh.pkl
# ./XNLI/test.s1.es
# ./XNLI/valid.s1.sw
# ./XNLI/valid.s2.bg
# ./XNLI/test.s2.ur
# ./XNLI/valid.s1.th
# ./XNLI/test.s1.en
# ./XNLI/test.s2.vi.pkl
# ./XNLI/test.s1.zh
# ./XNLI/valid.s2.zh
# ./XNLI/train.s1.en
# ./XNLI/valid.s2.zh.pkl
# ./XNLI/valid.s2.sw
# ./XNLI/valid.s2.fr.pkl
# ./XNLI/test.s2.tr.pkl
# ./XNLI/valid.label.ru
# ./XNLI/test.label.sw
# ./XNLI/valid.s1.en.pkl
# ./XNLI/valid.s1.hi.pkl
# ./XNLI/valid.s2.ur
# ./XNLI/test.s1.bg
# ./XNLI/valid.s2.tr
# ./XNLI/valid.s1.el.pkl
# ./XNLI/valid.s2.en.pkl
# ./XNLI/valid.s1.ru.pkl
# ./XNLI/valid.s1.tr.pkl
# ./XNLI/valid.s2.ur.pkl
# ./XNLI/test.s1.zh.pkl
# ./XNLI/test.s2.sw
# ./XNLI/test.label.el
# ./XNLI/test.label.vi
# ./XNLI/valid.s2.de.pkl
# ./XNLI/test.s2.ar.pkl
# ./XNLI/valid.s2.th
# ./XNLI/test.s1.hi.pkl
# ./XNLI/train.s2.en.pkl
# ./XNLI/valid.s1.ar
